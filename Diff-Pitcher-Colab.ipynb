# %% [markdown]
# # **A simple notebook for tuning voices.**

# %%
#@markdown # Clone Repo and install dependences
# !git clone https://github.com/JossCamp/DiffPitcher-Colab.git
# %cd /content/DiffPitcher-Colab
# !pip install -r requirements.txt

# %%
#@markdown # Download Models
# %cd /content/DiffPitcher-Colab/ckpts
# !mkdir -p bigvgan_24khz_100band
# !mkdir -p ckpt_transformer_pitch
# !gdown 1kMCEPlhiSPsUhDhE0MH3wzpZE7vrw94h
# %cd "/content/DiffPitcher-Colab/ckpts/bigvgan_24khz_100band"
# !gdown 1PLlvSZpTRKM6pswGAoeSXqfoB96UwZTj
# !gdown 1NOU6YzieaNjy3TCeItXgJ32h2HDhMZmr
# %cd "/content/DiffPitcher-Colab/ckpts/ckpt_transformer_pitch"
# !gdown 17L4yKg5LEQ14ikm4O8gjsT5aZAvBePwf
# %cd /content/DiffPitcher-Colab

# %% [markdown]
# **Template-based automatic pitch correction:**
# Use a third voice as a reference.

# %%
# !python template_based_apc.py --i examples/off-key.wav --r examples/reference.wav --o output_template.wav

# %% [markdown]
# **Score-based automatic pitch correction:**
# Use a midi file as a reference.

# %%
# !python score_based_apc.py --i examples/score_vocal.wav --r examples/score_midi.midi --o output_score.wav
